# %%
# !pip install scapy

# %%
from scapy.all import *
# Out:
# C:\Users\eniko\anaconda3\Lib\site-packages\scapy\layers\ipsec.py:469: CryptographyDeprecationWarning: Blowfish has been deprecated
#   cipher=algorithms.Blowfish,
# C:\Users\eniko\anaconda3\Lib\site-packages\scapy\layers\ipsec.py:483: CryptographyDeprecationWarning: CAST5 has been deprecated
#   cipher=algorithms.CAST5,

# %%
def process_packet(packet):
    packet.show()

# %%
sniff(prn = process_packet, count=20, filter='port 80', store=0) ## store=0 - not to store in the memory
# Out:
# ###[ Ethernet ]###
#   dst       = e0:19:54:60:29:70
#   src       = 9c:2f:9d:53:cf:b7
#   type      = IPv6
# ###[ IPv6 ]###
#      version   = 6
#      tc        = 0
#      fl        = 190490
#      plen      = 32
#      nh        = TCP
#      hlim      = 64
#      src       = 2a0c:5a85:6603:5b00:2149:bc08:7098:522d
#      dst       = 2606:2800:133:672:1e5f:2264:1854:1189
# ###[ TCP ]###
#         sport     = 57107
#         dport     = http
#         seq       = 3952183142
#         ack       = 0
#         dataofs   = 8
#         reserved  = 0
#         flags     = S
#         window    = 64800
#         chksum    = 0x79af
#         urgptr    = 0
#         options   = [('MSS', 1440), ('NOP', None), ('WScale', 8), ('NOP', None), ('NOP', None), ('SAckOK', b'')]
#
# ###[ Ethernet ]###
#   dst       = 9c:2f:9d:53:cf:b7
#   src       = e0:19:54:60:29:70
#   type      = IPv6
# ###[ IPv6 ]###
#      version   = 6
#      tc        = 0
#      fl        = 1006396
#      plen      = 32
# ...
